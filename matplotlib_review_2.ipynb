# %% [markdown]
# <a href="https://colab.research.google.com/github/jangje0908/sesac/blob/main/matplotlib_review_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Named Colors

# %%
color_list = ['b', 'g', 'r', 'c', 'm', 'y']

fig, ax = plt.subplots(figsize=(5, 10))

ax.set_xlim([-1, 1])
ax.set_ylim([-1, len(color_list)])

for c_idx, c in enumerate(color_list):
  ax.text(0, c_idx, "color="+c, fontsize=20, ha='center', color=c)

# %% [markdown]
# ## ax.plot and ax.scatter

# %%
np.random.seed(0)

n_data = 100
x_data = np.random.normal(0, 1, (n_data, ))   # 정규분포 따르게 랜덤으로 / 평균, 표준편차, 원하는 사이즈로 뽑음
y_data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(7, 7))

ax.scatter(x_data, y_data, s=100)

# %%
np.random.seed(0)

n_data = 100
x_data = np.random.normal(0, 1, (n_data, ))   # 정규분포 따르게 랜덤으로 / 평균, 표준편차, 원하는 사이즈로 뽑음
y_data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(7, 7))

ax.plot(x_data, y_data, 'o', markersize=10)

# %%
np.random.seed(0)

x_min, x_max = -5, 5
n_data = 300

x_data = np.random.uniform(x_min, x_max, n_data)
y_data = x_data + 0.5*np.random.normal(0, 1, n_data)

pred_x = np.linspace(x_min, x_max, 2)
pred_y = pred_x

fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(x_data, y_data)

ax.plot(pred_x, pred_y, color='r', linewidth=3)

# %% [markdown]
# ## Size Array and Color Array

# %%
n_data = 10
x_data = np.linspace(0, 10, n_data)
y_data = np.linspace(0, 10, n_data)

s_arr = np.linspace(10, 500, n_data)

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x_data, y_data, s=s_arr)

# %%
n_data = 10
x_data = np.linspace(0, 10, n_data)
y_data = np.linspace(0, 10, n_data)

c_arr = [(c/n_data, c/n_data, c/n_data) for c in range(n_data)]

fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(x_data, y_data, s=500, c=c_arr)

# %%
n_data = 10
x_data = np.linspace(0, 10, n_data)
y_data = np.linspace(0, 10, n_data)

s_arr = np.linspace(10, 500, n_data)
c_arr = [(c/n_data, c/n_data, c/n_data) for c in range(n_data)]

fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(x_data, y_data, s=s_arr, c=c_arr)

# %%
np.random.seed(0)

n_data = 500
x_data = np.random.normal(0, 1, size=(n_data, ))
y_data = np.random.normal(0, 1, size=(n_data, ))
s_arr = np.random.uniform(100, 500, n_data)
c_arr = [np.random.uniform(0, 1, 3) for _ in range(n_data)]

fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(x_data, y_data, s=s_arr, c=c_arr, alpha=0.5)

# %% [markdown]
# ## Advanced Markers

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(0, 0, s=10000, facecolor='r', edgecolor='b', linewidth=5)

# %%
n_data = 100
x_data = np.random.normal(0, 1, (n_data, ))
y_data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(x_data, y_data, s=300, facecolor='w', edgecolor='tab:blue', linewidth=5)

# %%
n_data = 100
x_data = np.random.normal(0, 1, (n_data, ))
y_data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(x_data, y_data, s=300, facecolor='None', edgecolor='tab:blue', linewidth=5)
